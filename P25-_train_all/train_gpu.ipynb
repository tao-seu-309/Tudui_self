# %% [markdown]
# # 1. 利用GPU训练(一)
# 能进行GPU训练部分: 三部分可添加 .cuda(): 网络模型, 数据（imgs，targets）, 损失函数
#
# 在上一节视频中 train.py 的基础上,增加.cuda()和增加测试时间的计算

# %%
# 准备数据集
import torch
import torchvision
from torch.utils.tensorboard import SummaryWriter

from model import *
from torch.utils.data import DataLoader
import time

train_data = torchvision.datasets.CIFAR10(root="../../dataset",train=True,transform=torchvision.transforms.ToTensor(),
                                          download=True)
test_data = torchvision.datasets.CIFAR10(root="../../dataset",train=False,transform=torchvision.transforms.ToTensor(),
                                          download=True)

# 查看数据集大小 length 长度
train_data_size = len(train_data)
test_data_size  = len(test_data)
print("训练数据集长度为:{}",format(train_data_size))
print("测试数据集长度为:{}",format(test_data_size))

# 利用 DataLoader 来加载数据集
train_dataloader = DataLoader(train_data,batch_size=64)
test_dataloader = DataLoader(test_data,batch_size=64)

# 创建网络模型
tudui = Tudui()

# 定义损失函数 用交叉熵
loss_fn = nn.CrossEntropyLoss()

# 判断是否可用cuda
if torch.cuda.is_available():
    print("torch.cuda.is_available")
    tudui = tudui.cuda() # 网络模型转移到cuda
    loss_fn = loss_fn.cuda()



# 定义优化器 选择的是随机梯度下降
# 1e-2 = 1*(10)^(-2) = 1/100 =0.01
learning_rate = 1e-2
optimizer = torch.optim.SGD(tudui.parameters(),lr=learning_rate)

# 设置训练网络的一些参数
    # 记录训练的次数
total_train_step = 0
    # 记录测试的次数
total_test_step = 0
    # 训练的轮数
epoch = 10


# 添加tensorboard
writer = SummaryWriter("../net_logs")



for i in range(epoch):
    print("-----------第{}轮训练开始-----------".format(i+1))
    start_time = time.time()
    tudui.train()
    # -- 训练步骤开始
    for data in train_dataloader:
        imgs,targets = data
        if torch.cuda.is_available():
            imgs ,targets = imgs.cuda(), targets.cuda()
        outputs = tudui(imgs)
        loss = loss_fn(outputs,targets)

        # 优化器优化模型
        # 利用优化器将梯度清零
        optimizer.zero_grad()
        # 利用反向传播得到每个梯度的结点
        loss.backward()
        # 调用优化器
        optimizer.step()

        # 训练次数+1
        total_train_step += 1
        if total_train_step % 100 == 0:
            print("训练次数:{},Loss:{}".format(total_train_step,loss))
            writer.add_scalar("train_loss",loss.item(), total_train_step)

    # -- 测试步骤开始
    # 计算整个数据集上的loss
    total_test_loss = 0
    # 计算整体的正确率 整体正确的个数 初始为0
    total_true_num = 0
    tudui.eval()
    with torch.no_grad():
        for data in test_dataloader:
            imgs,targets = data
            if torch.cuda.is_available():
                imgs ,targets = imgs.cuda(), targets.cuda()
            outputs = tudui(imgs)
            # 计算数据的损失
            loss = loss_fn(outputs,targets)
            # 计算整体损失
            total_test_loss = total_test_loss + loss

            # 计算准确率
            batch_true_num = (outputs.argmax(1)==targets).sum()
            total_true_num += batch_true_num         
    test_accuracy = total_true_num/test_data_size

    print("整体测试集上的loss:{}".format(total_test_loss))
    print(f"整体测试集上的正确率:{test_accuracy}")

    writer.add_scalar("test_2_loss",total_test_loss, total_test_step)
    writer.add_scalar("test_2_accuracy",test_accuracy,total_test_step)

    total_test_step += 1
    print(f"-----------第{total_test_step}轮测试结束-----------")    

    # 保存训练时每一轮的模型
    torch.save(tudui, "./model_pth/gpu_tudui_{}.pth".format(i))
    print('模型已保存')
    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"第{i}轮 Elapsed time: {elapsed_time}")
writer.close()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# 训练数据集长度为:{} 50000
# 测试数据集长度为:{} 10000
# torch.cuda.is_available
# -----------第1轮训练开始-----------
# 训练次数:100,Loss:2.2954437732696533
# 训练次数:200,Loss:2.2895901203155518
# 训练次数:300,Loss:2.278843879699707
# 训练次数:400,Loss:2.2362146377563477
# 训练次数:500,Loss:2.1171886920928955
# 训练次数:600,Loss:2.069493055343628
# 训练次数:700,Loss:2.0062482357025146
# 整体测试集上的loss:314.2009582519531
# 整体测试集上的正确率:0.27559998631477356
# -----------第1轮测试结束-----------
# 模型已保存
# 第0轮 Elapsed time: 17.186070442199707
# -----------第2轮训练开始-----------
# 训练次数:800,Loss:1.9224035739898682
# 训练次数:900,Loss:1.858345866203308
# 训练次数:1000,Loss:1.9357198476791382
# 训练次数:1100,Loss:1.9857430458068848
# 训练次数:1200,Loss:1.7319587469100952
# 训练次数:1300,Loss:1.6944974660873413
# 训练次数:1400,Loss:1.7629321813583374
# 训练次数:1500,Loss:1.8012839555740356
# 整体测试集上的loss:310.1408996582031
# 整体测试集上的正确率:0.30300000309944153
# -----------第2轮测试结束-----------
# 模型已保存
# 第1轮 Elapsed time: 17.169941186904907
# -----------第3轮训练开始-----------
# 训练次数:1600,Loss:1.797836184501648
# 训练次数:1700,Loss:1.6748645305633545
# 训练次数:1800,Loss:1.945051908493042
# 训练次数:1900,Loss:1.7315924167633057
# 训练次数:2000,Loss:1.906532645225525
# 训练次数:2100,Loss:1.5600528717041016
# 训练次数:2200,Loss:1.494645118713379
# 训练次数:2300,Loss:1.8275063037872314
# 整体测试集上的loss:265.3623352050781
# 整体测试集上的正确率:0.3944999873638153
# -----------第3轮测试结束-----------
# 模型已保存
# 第2轮 Elapsed time: 17.15973424911499
# -----------第4轮训练开始-----------
# 训练次数:2400,Loss:1.7647050619125366
# 训练次数:2500,Loss:1.3333934545516968
# 训练次数:2600,Loss:1.5836682319641113
# 训练次数:2700,Loss:1.6955982446670532
# 训练次数:2800,Loss:1.4946773052215576
# 训练次数:2900,Loss:1.587477445602417
# 训练次数:3000,Loss:1.3492876291275024
# 训练次数:3100,Loss:1.520739197731018
# 整体测试集上的loss:251.52313232421875
# 整体测试集上的正确率:0.4250999987125397
# -----------第4轮测试结束-----------
# 模型已保存
# 第3轮 Elapsed time: 17.20150589942932
# -----------第5轮训练开始-----------
# 训练次数:3200,Loss:1.385438084602356
# 训练次数:3300,Loss:1.4857213497161865
# 训练次数:3400,Loss:1.5135538578033447
# 训练次数:3500,Loss:1.5747624635696411
# 训练次数:3600,Loss:1.5940845012664795
# 训练次数:3700,Loss:1.3593016862869263
# 训练次数:3800,Loss:1.2638133764266968
# 训练次数:3900,Loss:1.4174600839614868
# 整体测试集上的loss:245.42694091796875
# 整体测试集上的正确率:0.4341000020503998
# -----------第5轮测试结束-----------
# 模型已保存
# 第4轮 Elapsed time: 17.203380346298218
# -----------第6轮训练开始-----------
# 训练次数:4000,Loss:1.4094735383987427
# 训练次数:4100,Loss:1.4574089050292969
# 训练次数:4200,Loss:1.5092995166778564
# 训练次数:4300,Loss:1.1943708658218384
# 训练次数:4400,Loss:1.1639788150787354
# 训练次数:4500,Loss:1.3344446420669556
# 训练次数:4600,Loss:1.4308390617370605
# 整体测试集上的loss:236.7279815673828
# 整体测试集上的正确率:0.4536999762058258
# -----------第6轮测试结束-----------
# 模型已保存
# 第5轮 Elapsed time: 17.196736335754395
# -----------第7轮训练开始-----------
# 训练次数:4700,Loss:1.341640830039978
# 训练次数:4800,Loss:1.5409629344940186
# 训练次数:4900,Loss:1.4220879077911377
# 训练次数:5000,Loss:1.400186538696289
# 训练次数:5100,Loss:1.037709355354309
# 训练次数:5200,Loss:1.2990401983261108
# 训练次数:5300,Loss:1.2432924509048462
# 训练次数:5400,Loss:1.3594863414764404
# 整体测试集上的loss:227.85401916503906
# 整体测试集上的正确率:0.47360000014305115
# -----------第7轮测试结束-----------
# 模型已保存
# 第6轮 Elapsed time: 17.187716960906982
# -----------第8轮训练开始-----------
# 训练次数:5500,Loss:1.2106752395629883
# 训练次数:5600,Loss:1.214820146560669
# 训练次数:5700,Loss:1.2775572538375854
# 训练次数:5800,Loss:1.221739411354065
# 训练次数:5900,Loss:1.346828818321228
# 训练次数:6000,Loss:1.547135591506958
# 训练次数:6100,Loss:1.042157530784607
# 训练次数:6200,Loss:1.1090567111968994
# 整体测试集上的loss:217.6348876953125
# 整体测试集上的正确率:0.5030999779701233
# -----------第8轮测试结束-----------
# 模型已保存
# 第7轮 Elapsed time: 17.201623678207397
# -----------第9轮训练开始-----------
# 训练次数:6300,Loss:1.4036126136779785
# 训练次数:6400,Loss:1.1867833137512207
# 训练次数:6500,Loss:1.6057053804397583
# 训练次数:6600,Loss:1.0675458908081055
# 训练次数:6700,Loss:1.0664373636245728
# 训练次数:6800,Loss:1.201635718345642
# 训练次数:6900,Loss:1.1345093250274658
# 训练次数:7000,Loss:0.9186125993728638
# 整体测试集上的loss:207.09683227539062
# 整体测试集上的正确率:0.5288000106811523
# -----------第9轮测试结束-----------
# 模型已保存
# 第8轮 Elapsed time: 17.16570782661438
# -----------第10轮训练开始-----------
# 训练次数:7100,Loss:1.2391362190246582
# 训练次数:7200,Loss:1.0319536924362183
# 训练次数:7300,Loss:1.084030032157898
# 训练次数:7400,Loss:0.8568114638328552
# 训练次数:7500,Loss:1.1984859704971313
# 训练次数:7600,Loss:1.2505735158920288
# 训练次数:7700,Loss:0.8847914338111877
# 训练次数:7800,Loss:1.2518779039382935
# 整体测试集上的loss:198.36563110351562
# 整体测试集上的正确率:0.5539000034332275
# -----------第10轮测试结束-----------
# 模型已保存
# 第9轮 Elapsed time: 17.18690776824951

# %% [markdown]
# # 2. 利用GPU训练(二)
#
# .to(device) # 这种方式更常用~
#
# `device = torch.device("cpu)`
#
# `device = torch.device(“cuda”)`
#
# 当电脑上有多张显卡时: 可以指定显卡
#
# `device = torch.device(“cuda:0”)` # 制定第一个显卡
#
# `device = torch.device(“cuda:1”)` # 制定第二个显卡
#
#
# **train_gpu_2.py**
#
# 首先把train_gpu_1.py 里的代码复制过来 , 开改~
#
# 改动部分如下:
#
# 定义训练的设备: `device = torch.device('cuda')`
#
# 定义模型 :
#
# * 常见写法1 `tudui.to('device')`
# * 常见写法2 `device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')`
# * 修改损失函数: `loss_fn = loss_fn.to(device)`
#
# 修改训练和测试的cuda部分
#
# ​ `imgs = imgs.to(device)`
# ​ `targets = targets.to(device)`

# %%
import torch

# Check the number of GPUs available
gpu_count = torch.cuda.device_count()
gpu_count
# Out:
# 1

# %%
# 准备数据集
import torch
import torchvision
from torch.utils.tensorboard import SummaryWriter

from model import *
from torch.utils.data import DataLoader
import time

train_data = torchvision.datasets.CIFAR10(root="../../dataset",train=True,transform=torchvision.transforms.ToTensor(),
                                          download=True)
test_data = torchvision.datasets.CIFAR10(root="../../dataset",train=False,transform=torchvision.transforms.ToTensor(),
                                          download=True)

# 查看数据集大小 length 长度
train_data_size = len(train_data)
test_data_size  = len(test_data)
print("训练数据集长度为:{}",format(train_data_size))
print("测试数据集长度为:{}",format(test_data_size))

# 利用 DataLoader 来加载数据集
train_dataloader = DataLoader(train_data,batch_size=64)
test_dataloader = DataLoader(test_data,batch_size=64)

#######################
# 判断是否可用cuda
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#######################

# 创建网络模型
tudui = Tudui().to(device)

# 定义损失函数 用交叉熵
loss_fn = nn.CrossEntropyLoss().to(device)

# 定义优化器 选择的是随机梯度下降
# 1e-2 = 1*(10)^(-2) = 1/100 =0.01
learning_rate = 1e-2
optimizer = torch.optim.SGD(tudui.parameters(),lr=learning_rate)

# 设置训练网络的一些参数
    # 记录训练的次数
total_train_step = 0
    # 记录测试的次数
total_test_step = 0
    # 训练的轮数
epoch = 10


# 添加tensorboard
writer = SummaryWriter("../net_logs")



for i in range(epoch):
    print("-----------第{}轮训练开始-----------".format(i+1))
    start_time = time.time()
    tudui.train()
    # -- 训练步骤开始
    for data in train_dataloader:
        imgs,targets = data
        if torch.cuda.is_available():
            imgs ,targets = imgs.to(device), targets.to(device)
        outputs = tudui(imgs)
        loss = loss_fn(outputs,targets)

        # 优化器优化模型
        # 利用优化器将梯度清零
        optimizer.zero_grad()
        # 利用反向传播得到每个梯度的结点
        loss.backward()
        # 调用优化器
        optimizer.step()

        # 训练次数+1
        total_train_step += 1
        if total_train_step % 100 == 0:
            print("训练次数:{},Loss:{}".format(total_train_step,loss))
            writer.add_scalar("gpu_2_train_loss",loss.item(), total_train_step)

    # -- 测试步骤开始
    # 计算整个数据集上的loss
    total_test_loss = 0
    # 计算整体的正确率 整体正确的个数 初始为0
    total_true_num = 0
    tudui.eval()
    with torch.no_grad():
        for data in test_dataloader:
            imgs,targets = data
            if torch.cuda.is_available():
                imgs ,targets = imgs.to(device), targets.to(device)
            outputs = tudui(imgs)
            # 计算数据的损失
            loss = loss_fn(outputs,targets)
            # 计算整体损失
            total_test_loss = total_test_loss + loss

            # 计算准确率
            batch_true_num = (outputs.argmax(1)==targets).sum()
            total_true_num += batch_true_num         
    test_accuracy = total_true_num/test_data_size

    print("整体测试集上的loss:{}".format(total_test_loss))
    print(f"整体测试集上的正确率:{test_accuracy}")

    writer.add_scalar("test_gpu_2_loss",total_test_loss, total_test_step)
    writer.add_scalar("test_gpu_2_accuracy",test_accuracy,total_test_step)

    total_test_step += 1
    print(f"-----------第{total_test_step}轮测试结束-----------")    

    # 保存训练时每一轮的模型
    torch.save(tudui, "./model_pth/gpu_2_tudui_{}.pth".format(i))
    print('模型已保存')
    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"第{i}轮 Elapsed time: {elapsed_time}")
writer.close()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# 训练数据集长度为:{} 50000
# 测试数据集长度为:{} 10000
# -----------第1轮训练开始-----------
# 训练次数:100,Loss:2.288994550704956
# 训练次数:200,Loss:2.287259340286255
# 训练次数:300,Loss:2.277855396270752
# 训练次数:400,Loss:2.230238199234009
# 训练次数:500,Loss:2.1387710571289062
# 训练次数:600,Loss:2.040024518966675
# 训练次数:700,Loss:2.0002012252807617
# 整体测试集上的loss:315.3457336425781
# 整体测试集上的正确率:0.2766999900341034
# -----------第1轮测试结束-----------
# 模型已保存
# 第0轮 Elapsed time: 17.261840343475342
# -----------第2轮训练开始-----------
# 训练次数:800,Loss:1.8995734453201294
# 训练次数:900,Loss:1.8302090167999268
# 训练次数:1000,Loss:1.9018371105194092
# 训练次数:1100,Loss:2.0305349826812744
# 训练次数:1200,Loss:1.666668176651001
# 训练次数:1300,Loss:1.6292837858200073
# 训练次数:1400,Loss:1.7061986923217773
# 训练次数:1500,Loss:1.799957275390625
# 整体测试集上的loss:298.57867431640625
# 整体测试集上的正确率:0.3231000006198883
# -----------第2轮测试结束-----------
# 模型已保存
# 第1轮 Elapsed time: 17.24276041984558
# -----------第3轮训练开始-----------
# 训练次数:1600,Loss:1.7362592220306396
# 训练次数:1700,Loss:1.636801838874817
# 训练次数:1800,Loss:1.9172419309616089
# 训练次数:1900,Loss:1.6882492303848267
# 训练次数:2000,Loss:1.889000415802002
# 训练次数:2100,Loss:1.5038803815841675
# 训练次数:2200,Loss:1.454390048980713
# 训练次数:2300,Loss:1.7674102783203125
# 整体测试集上的loss:264.2074890136719
# 整体测试集上的正确率:0.3962000012397766
# -----------第3轮测试结束-----------
# 模型已保存
# 第2轮 Elapsed time: 17.241366147994995
# -----------第4轮训练开始-----------
# 训练次数:2400,Loss:1.6950932741165161
# 训练次数:2500,Loss:1.349311113357544
# 训练次数:2600,Loss:1.5893508195877075
# 训练次数:2700,Loss:1.6374608278274536
# 训练次数:2800,Loss:1.4999518394470215
# 训练次数:2900,Loss:1.607941746711731
# 训练次数:3000,Loss:1.3490153551101685
# 训练次数:3100,Loss:1.5260095596313477
# 整体测试集上的loss:257.8485412597656
# 整体测试集上的正确率:0.4123999774456024
# -----------第4轮测试结束-----------
# 模型已保存
# 第3轮 Elapsed time: 17.221927165985107
# -----------第5轮训练开始-----------
# 训练次数:3200,Loss:1.3408807516098022
# 训练次数:3300,Loss:1.4791405200958252
# 训练次数:3400,Loss:1.4217607975006104
# 训练次数:3500,Loss:1.5388908386230469
# 训练次数:3600,Loss:1.5465432405471802
# 训练次数:3700,Loss:1.341290831565857
# 训练次数:3800,Loss:1.2532035112380981
# 训练次数:3900,Loss:1.4422696828842163
# 整体测试集上的loss:251.87802124023438
# 整体测试集上的正确率:0.4245999753475189
# -----------第5轮测试结束-----------
# 模型已保存
# 第4轮 Elapsed time: 17.21407175064087
# -----------第6轮训练开始-----------
# 训练次数:4000,Loss:1.395228624343872
# 训练次数:4100,Loss:1.4100764989852905
# 训练次数:4200,Loss:1.5081052780151367
# 训练次数:4300,Loss:1.1909534931182861
# 训练次数:4400,Loss:1.12663996219635
# 训练次数:4500,Loss:1.3630341291427612
# 训练次数:4600,Loss:1.3469566106796265
# 整体测试集上的loss:241.68148803710938
# 整体测试集上的正确率:0.44509997963905334
# -----------第6轮测试结束-----------
# 模型已保存
# 第5轮 Elapsed time: 17.186978101730347
# -----------第7轮训练开始-----------
# 训练次数:4700,Loss:1.3050233125686646
# 训练次数:4800,Loss:1.455528974533081
# 训练次数:4900,Loss:1.390496015548706
# 训练次数:5000,Loss:1.3832323551177979
# 训练次数:5100,Loss:1.035264015197754
# 训练次数:5200,Loss:1.3274017572402954
# 训练次数:5300,Loss:1.1786813735961914
# 训练次数:5400,Loss:1.4025182723999023
# 整体测试集上的loss:234.3791961669922
# 整体测试集上的正确率:0.4625999927520752
# -----------第7轮测试结束-----------
# 模型已保存
# 第6轮 Elapsed time: 17.22213912010193
# -----------第8轮训练开始-----------
# 训练次数:5500,Loss:1.2381367683410645
# 训练次数:5600,Loss:1.199677586555481
# 训练次数:5700,Loss:1.1999701261520386
# 训练次数:5800,Loss:1.2410224676132202
# 训练次数:5900,Loss:1.331335186958313
# 训练次数:6000,Loss:1.4953323602676392
# 训练次数:6100,Loss:1.047459363937378
# 训练次数:6200,Loss:1.062609314918518
# 整体测试集上的loss:222.85140991210938
# 整体测试集上的正确率:0.4926999807357788
# -----------第8轮测试结束-----------
# 模型已保存
# 第7轮 Elapsed time: 17.215521335601807
# -----------第9轮训练开始-----------
# 训练次数:6300,Loss:1.430081844329834
# 训练次数:6400,Loss:1.1019542217254639
# 训练次数:6500,Loss:1.5576003789901733
# 训练次数:6600,Loss:1.1034733057022095
# 训练次数:6700,Loss:1.0495120286941528
# 训练次数:6800,Loss:1.1812129020690918
# 训练次数:6900,Loss:1.1112864017486572
# 训练次数:7000,Loss:0.8897143602371216
# 整体测试集上的loss:211.79685974121094
# 整体测试集上的正确率:0.5187000036239624
# -----------第9轮测试结束-----------
# 模型已保存
# 第8轮 Elapsed time: 17.291462898254395
# -----------第10轮训练开始-----------
# 训练次数:7100,Loss:1.2122048139572144
# 训练次数:7200,Loss:0.9465047717094421
# 训练次数:7300,Loss:1.1324762105941772
# 训练次数:7400,Loss:0.8025851249694824
# 训练次数:7500,Loss:1.252802848815918
# 训练次数:7600,Loss:1.235945224761963
# 训练次数:7700,Loss:0.9051192402839661
# 训练次数:7800,Loss:1.272104024887085
# 整体测试集上的loss:204.3824920654297
# 整体测试集上的正确率:0.5407999753952026
# -----------第10轮测试结束-----------
# 模型已保存
# 第9轮 Elapsed time: 17.228137016296387

# %% [markdown]
# # 3. 加载模型，继续训练
# test代码测试出来识别不了airplane，所以再训练10轮再试试

# %%
# test代码测试出来识别不了airplane，所以再训练10轮再试试

# 前面省略，需要先运行第一块代码
model = torch.load("/storage/pt/AW_STUDY/pytorch-tutorial-tudui/study_self/P25-_train_all/model_pth/gpu_3_tudui_9.pth")
print(model)

# 定义损失函数 用交叉熵
loss_fn = nn.CrossEntropyLoss().to(device)

# 定义优化器 选择的是随机梯度下降
# 1e-2 = 1*(10)^(-2) = 1/100 =0.01
learning_rate = 1e-2
optimizer = torch.optim.SGD(model.parameters(),lr=learning_rate)

# 设置训练网络的一些参数
    # 记录训练的次数
total_train_step = 0
    # 记录测试的次数
total_test_step = 0
    # 训练的轮数
epoch = 10

# 添加tensorboard
writer = SummaryWriter("../net_logs")

for i in range(epoch):
    print("-----------第{}轮训练开始-----------".format(i+1))
    start_time = time.time()
    model.train()
    # -- 训练步骤开始
    for data in train_dataloader:
        imgs,targets = data
        if torch.cuda.is_available():
            imgs ,targets = imgs.to(device), targets.to(device)
        outputs = model(imgs)
        loss = loss_fn(outputs,targets)

        # 优化器优化模型
        # 利用优化器将梯度清零
        optimizer.zero_grad()
        # 利用反向传播得到每个梯度的结点
        loss.backward()
        # 调用优化器
        optimizer.step()

        # 训练次数+1
        total_train_step += 1
        if total_train_step % 100 == 0:
            print("训练次数:{},Loss:{}".format(total_train_step,loss))
            writer.add_scalar("gpu_2_train_loss",loss.item(), total_train_step)

    # -- 测试步骤开始
    # 计算整个数据集上的loss
    total_test_loss = 0
    # 计算整体的正确率 整体正确的个数 初始为0
    total_true_num = 0
    model.eval()
    with torch.no_grad():
        for data in test_dataloader:
            imgs,targets = data
            if torch.cuda.is_available():
                imgs ,targets = imgs.to(device), targets.to(device)
            outputs = model(imgs)
            # 计算数据的损失
            loss = loss_fn(outputs,targets)
            # 计算整体损失
            total_test_loss = total_test_loss + loss

            # 计算准确率
            batch_true_num = (outputs.argmax(1)==targets).sum()
            total_true_num += batch_true_num         
    test_accuracy = total_true_num/test_data_size

    print("整体测试集上的loss:{}".format(total_test_loss))
    print(f"整体测试集上的正确率:{test_accuracy}")

    writer.add_scalar("test_gpu_2_loss",total_test_loss, total_test_step)
    writer.add_scalar("test_gpu_2_accuracy",test_accuracy,total_test_step)

    total_test_step += 1
    print(f"-----------第{total_test_step}轮测试结束-----------")    

    # 保存训练时每一轮的模型
    torch.save(model, "./model_pth/gpu_4_tudui_{}.pth".format(i))
    print('模型已保存')
    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"第{i}轮 Elapsed time: {elapsed_time}")
writer.close()
# Out:
# Tudui(
#   (model): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (2): Conv2d(32, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Flatten(start_dim=1, end_dim=-1)
#     (7): Linear(in_features=1024, out_features=64, bias=True)
#     (8): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# -----------第1轮训练开始-----------
# 训练次数:100,Loss:0.5573392510414124
# 训练次数:200,Loss:0.618193507194519
# 训练次数:300,Loss:0.6381914615631104
# 训练次数:400,Loss:0.663777768611908
# 训练次数:500,Loss:0.5712800621986389
# 训练次数:600,Loss:0.5486220121383667
# 训练次数:700,Loss:0.6988285183906555
# 整体测试集上的loss:177.7161407470703
# 整体测试集上的正确率:0.6408999562263489
# -----------第1轮测试结束-----------
# 模型已保存
# 第0轮 Elapsed time: 17.283642530441284
# -----------第2轮训练开始-----------
# 训练次数:800,Loss:0.736667811870575
# 训练次数:900,Loss:0.45826610922813416
# 训练次数:1000,Loss:0.7214697599411011
# 训练次数:1100,Loss:0.6326403617858887
# 训练次数:1200,Loss:0.5472363829612732
# 训练次数:1300,Loss:0.538353681564331
# 训练次数:1400,Loss:0.40199580788612366
# 训练次数:1500,Loss:0.6681987047195435
# 整体测试集上的loss:178.79052734375
# 整体测试集上的正确率:0.6412999629974365
# -----------第2轮测试结束-----------
# 模型已保存
# 第1轮 Elapsed time: 17.311270475387573
# -----------第3轮训练开始-----------
# 训练次数:1600,Loss:0.5467589497566223
# 训练次数:1700,Loss:0.5322688221931458
# 训练次数:1800,Loss:0.5631504058837891
# 训练次数:1900,Loss:0.62736576795578
# 训练次数:2000,Loss:0.5273714065551758
# 训练次数:2100,Loss:0.4476594626903534
# 训练次数:2200,Loss:0.45984533429145813
# 训练次数:2300,Loss:0.587859570980072
# 整体测试集上的loss:181.72915649414062
# 整体测试集上的正确率:0.6401000022888184
# -----------第3轮测试结束-----------
# 模型已保存
# 第2轮 Elapsed time: 17.236419200897217
# -----------第4轮训练开始-----------
# 训练次数:2400,Loss:0.6672763228416443
# 训练次数:2500,Loss:0.48069900274276733
# 训练次数:2600,Loss:0.5697371363639832
# 训练次数:2700,Loss:0.49944403767585754
# 训练次数:2800,Loss:0.4865940809249878
# 训练次数:2900,Loss:0.685455858707428
# 训练次数:3000,Loss:0.5587015151977539
# 训练次数:3100,Loss:0.5007466673851013
# 整体测试集上的loss:183.82144165039062
# 整体测试集上的正确率:0.6402999758720398
# -----------第4轮测试结束-----------
# 模型已保存
# 第3轮 Elapsed time: 17.282448291778564
# -----------第5轮训练开始-----------
# 训练次数:3200,Loss:0.4136245846748352
# 训练次数:3300,Loss:0.5112296938896179
# 训练次数:3400,Loss:0.7519818544387817
# 训练次数:3500,Loss:0.48055943846702576
# 训练次数:3600,Loss:0.6092867851257324
# 训练次数:3700,Loss:0.44524532556533813
# 训练次数:3800,Loss:0.6580322980880737
# 训练次数:3900,Loss:0.5824467539787292
# 整体测试集上的loss:186.18309020996094
# 整体测试集上的正确率:0.6394000053405762
# -----------第5轮测试结束-----------
# 模型已保存
# 第4轮 Elapsed time: 17.267263174057007
# -----------第6轮训练开始-----------
# 训练次数:4000,Loss:0.5824986696243286
# 训练次数:4100,Loss:0.707135021686554
# 训练次数:4200,Loss:0.7650115489959717
# 训练次数:4300,Loss:0.6496056318283081
# 训练次数:4400,Loss:0.44276338815689087
# 训练次数:4500,Loss:0.8015109300613403
# 训练次数:4600,Loss:0.5762501955032349
# 整体测试集上的loss:187.5246124267578
# 整体测试集上的正确率:0.6416999697685242
# -----------第6轮测试结束-----------
# 模型已保存
# 第5轮 Elapsed time: 17.217480421066284
# -----------第7轮训练开始-----------
# 训练次数:4700,Loss:0.39150717854499817
# 训练次数:4800,Loss:0.5291192531585693
# 训练次数:4900,Loss:0.5690160393714905
# 训练次数:5000,Loss:0.5133522748947144
# 训练次数:5100,Loss:0.3622573912143707
# 训练次数:5200,Loss:0.49323293566703796
# 训练次数:5300,Loss:0.3622514605522156
# 训练次数:5400,Loss:0.47371354699134827
# 整体测试集上的loss:187.77699279785156
# 整体测试集上的正确率:0.6450999975204468
# -----------第7轮测试结束-----------
# 模型已保存
# 第6轮 Elapsed time: 17.313249826431274
# -----------第8轮训练开始-----------
# 训练次数:5500,Loss:0.44298964738845825
# 训练次数:5600,Loss:0.43695056438446045
# 训练次数:5700,Loss:0.4660075008869171
# 训练次数:5800,Loss:0.4186335504055023
# 训练次数:5900,Loss:0.6465643644332886
# 训练次数:6000,Loss:0.6790122389793396
# 训练次数:6100,Loss:0.44136443734169006
# 训练次数:6200,Loss:0.45875582098960876
# 整体测试集上的loss:191.97450256347656
# 整体测试集上的正确率:0.6419000029563904
# -----------第8轮测试结束-----------
# 模型已保存
# 第7轮 Elapsed time: 17.30188751220703
# -----------第9轮训练开始-----------
# 训练次数:6300,Loss:0.49324649572372437
# 训练次数:6400,Loss:0.41396281123161316
# 训练次数:6500,Loss:0.6617709994316101
# 训练次数:6600,Loss:0.4975346028804779
# 训练次数:6700,Loss:0.42585623264312744
# 训练次数:6800,Loss:0.5373067855834961
# 训练次数:6900,Loss:0.4202488660812378
# 训练次数:7000,Loss:0.16592031717300415
# 整体测试集上的loss:194.84226989746094
# 整体测试集上的正确率:0.6426999568939209
# -----------第9轮测试结束-----------
# 模型已保存
# 第8轮 Elapsed time: 17.27880573272705
# -----------第10轮训练开始-----------
# 训练次数:7100,Loss:0.389498233795166
# 训练次数:7200,Loss:0.42547959089279175
# 训练次数:7300,Loss:0.3494003117084503
# 训练次数:7400,Loss:0.3783857524394989
# 训练次数:7500,Loss:0.38056910037994385
# 训练次数:7600,Loss:0.3666020631790161
# 训练次数:7700,Loss:0.38344913721084595
# 训练次数:7800,Loss:0.5084289908409119
# 整体测试集上的loss:199.516845703125
# 整体测试集上的正确率:0.6430000066757202
# -----------第10轮测试结束-----------
# 模型已保存
# 第9轮 Elapsed time: 17.244505882263184
